# %% [markdown]
# # Task 3: Neural Networks with TensorFlow/Keras
#
# ## Description
#
# In this task, I will build a simple feed-forward neural network using TensorFlow/Keras for image classification.
#
# I will use the MNIST handwritten digit dataset.
#
# The goal is to classify grayscale images of handwritten digits into one of 10 classes:
#
# 0, 1, 2, 3, 4, 5, 6, 7, 8, or 9.
#
# ## Objectives
#
# 1. Load and preprocess the dataset.
# 2. Visualize sample images.
# 3. Build a feed-forward neural network.
# 4. Train the model using backpropagation.
# 5. Evaluate the model using accuracy, precision, recall, and F1-score.
# 6. Visualize training and validation loss.
# 7. Visualize training and validation accuracy.
# 8. Make predictions.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os 

import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## Reproducibility
#
# Set a random seed so that our results are more consistent each time we run the notebook.

# %%
tf.keras.utils.set_random_seed(42)

# %% [markdown]
# ## Load Dataset
# Load the MNIST dataset using Keras.
#
# The dataset is already split into:
#
# - Training set
# - Testing set
#
# Each image is 28 by 28 pixels.
# Each label is an integer from 0 to 9.

# %%
local_path = os.path.abspath(r"C:\Users\Asus Gaming\Desktop\Project\Data Science\Codveda\dataset\mnist.npz")
(x_train, y_train), (x_test, y_test) = mnist.load_data(path=local_path)

print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
# Out:
#   Cell In[10], line 1
#     local_path = os.path.abspath("C:\Users\Asus Gaming\Desktop\Project\Data Science\Codveda\dataset\mnist.npz")
#                                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
